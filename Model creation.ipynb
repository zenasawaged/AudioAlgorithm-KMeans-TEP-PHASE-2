# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
# # loading our dataframes
#we will be using cleaned_df for our Audio Recommendation Algorithm Dataset sample.
cleaned_df = pd.read_csv('../TEP PHASE 2/train.csv')

# %%
df_f = pd.read_csv('../TEP PHASE 2/train.csv')

# %%
cleaned_df.describe()
# Out:
#        release_date           len        dating      violence    world/life  \
# count  28362.000000  28362.000000  28362.000000  28362.000000  28362.000000
# mean    1990.239652     73.030534      0.021110      0.118371      0.120984
# std       18.486997     41.831605      0.052366      0.178658      0.172216
# min     1950.000000      1.000000      0.000291      0.000284      0.000291
# 25%     1975.000000     42.000000      0.000923      0.001120      0.001170
# 50%     1991.000000     63.000000      0.001462      0.002506      0.006579
# 75%     2007.000000     93.000000      0.004049      0.192538      0.197854
# max     2019.000000    199.000000      0.647706      0.981781      0.962105
#
#          night/time  shake the audience  family/gospel      romantic  \
# count  28362.000000        28362.000000   28362.000000  28362.000000
# mean       0.057356            0.017418       0.017045      0.048676
# std        0.111892            0.040658       0.041968      0.106071
# ...

# %%
# To do Kmeans we have to drop all non-numerical columns 
numerical_df=df_f.drop(['artist_name','track_name','genre','topic'], axis=1)

# %%
#KMeans clustering

# Calculate within-cluster sum of squares (WCSS) for different values of K
# Plot the elbow method curve
WCSS = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(numerical_df)
    WCSS.append([i, kmeans.inertia_])
WCSS = pd.DataFrame(WCSS, columns=['number_of_clusters', 'distance'])
WCSS.set_index("number_of_clusters").plot()
plt.xlabel("Number of Clusters")
plt.ylabel("Distance (squared) to the Centroid")
# Out:
# Text(0, 0.5, 'Distance (squared) to the Centroid')

# %%
km = KMeans(n_clusters=3)
numerical_df['cluster'] = km.fit_predict(numerical_df)
# Out:
# /Users/zenasawaged/anaconda3/envs/phase1/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
numerical_df.head()
# Out:
#    release_date  len    dating  violence  world/life  night/time  \
# 0          1950   95  0.000598  0.063746    0.000598    0.000598
# 1          1950   51  0.035537  0.096777    0.443435    0.001284
# 2          1950   24  0.002770  0.002770    0.002770    0.002770
# 3          1950   54  0.048249  0.001548    0.001548    0.001548
# 4          1950   48  0.001350  0.001350    0.417772    0.001350
#
#    shake the audience  family/gospel  romantic  communication   obscene  \
# 0            0.000598       0.048857  0.017104       0.263751  0.000598
# 1            0.001284       0.027007  0.001284       0.001284  0.001284
# 2            0.002770       0.002770  0.158564       0.250668  0.002770
# 3            0.021500       0.001548  0.411536       0.001548  0.001548
# 4            0.001350       0.001350  0.463430       0.001350  0.001350
#
#       music  movement/places  light/visual perceptions  family/spiritual  \
# ...

# %%
numerical_df
# Out:
#        release_date  len    dating  violence  world/life  night/time  \
# 0              1950   95  0.000598  0.063746    0.000598    0.000598
# 1              1950   51  0.035537  0.096777    0.443435    0.001284
# 2              1950   24  0.002770  0.002770    0.002770    0.002770
# 3              1950   54  0.048249  0.001548    0.001548    0.001548
# 4              1950   48  0.001350  0.001350    0.417772    0.001350
# ...             ...  ...       ...       ...         ...         ...
# 28357          2019   78  0.001350  0.001350    0.001350    0.001350
# 28358          2019   67  0.001284  0.001284    0.035338    0.001284
# 28359          2019   77  0.001504  0.154302    0.168988    0.001504
# 28360          2019   67  0.001196  0.001196    0.001196    0.001196
# 28361          2019   83  0.001012  0.075202    0.001012    0.001012
#
#        shake the audience  family/gospel  romantic  communication   obscene  \
# ...

# %%
numerical_df.cluster.value_counts()
# Out:
# cluster
# 0    14039
# 2    10389
# 1     3934
# Name: count, dtype: int64

# %%
#According to the elbow plot, best number of clusters is 3

# %%
We will start off with an analysis on 2 variables: sadness and dating .

# %%
# create a Means object with this optimal number of clusters. Name this object 'kmeans'
kmeans = KMeans(n_clusters=3)
kmeans
# fit this Means object using my "numerical_df" data
kmeans.fit_predict(numerical_df[['sadness', 'dating']])
# Out:
# /Users/zenasawaged/anaconda3/envs/phase1/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([2, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
# Generate labels for the dataset
labels = kmeans.fit_predict(numerical_df[['sadness', 'dating']])
labels
# Out:
# /Users/zenasawaged/anaconda3/envs/phase1/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([2, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
# output the centroids of your clusters
kmeans.cluster_centers_
# Out:
# array([[0.0242024 , 0.02130951],
#        [0.52942271, 0.01749733],
#        [0.30423389, 0.02217827]])

# %%
plt.figure(figsize = (14, 8))

plt.scatter(numerical_df[:, 0],numerical_df[:,1], c = kmeans.labels_, s= 105)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'red', s = 250)
plt.title('Clusters of Audio patterns\n',fontsize = 20)
plt.xlabel('sadness')
plt.ylabel('dating')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/phase1/lib/python3.9/site-packages/pandas/_libs/index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[50], line 3
#       1 plt.figure(figsize = (14, 8))
# ...

# %%
import pandas as pd

# %%
# # loading our dataframes
#we will be using df_f for our Audio Recommendation Algorithm Dataset sample.
df_f = pd.read_csv('../TEP PHASE 2/train.csv')

# %%
#First let's see what is the shappe of each dataframe 
print("Audio Recommendation Algorithm Dataset:", df_f.shape)
# Out:
# Audio Recommendation Algorithm Dataset: (28362, 24)

# %%
#  We already checked for null values in initial EDA, so Lets drop "'Unnamed: 0'" as there are no values and 'lyrics' as per instruction

cleaned_df= df_f.drop(['Unnamed: 0','lyrics'], axis=1)

# %%
cleaned_df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28357               mack 10                10 million ways          2019
# 28358                m.o.p.  ante up (robbin hoodz theory)          2019
# 28359                  nine                  whutcha want?          2019
# 28360            will smith                         switch          2019
# 28361                 jeezy                         r.i.p.          2019
#
#          genre  len    dating  violence  world/life  night/time  \
# ...

# %%
# As there aren't any null values or incorrectly formatted data we will go ahead and save this dataframe as a new csv file to be used in the next step.

cleaned_df.to_csv("../TEP PHASE 2/train.csv", index=False)
